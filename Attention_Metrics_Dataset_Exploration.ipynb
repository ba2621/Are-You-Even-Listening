# %% [markdown]
# <a href="https://colab.research.google.com/github/ba2621/Are-You-Even-Listening/blob/main/Attention_Metrics_Dataset_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !head -n 5 attention_metrics.jsonl
# Out:
# {"id": "alpaca:22052", "dataset": "alpaca", "constraint_tags": [], "seq_len": 22, "p_len": 19, "u_len": 1, "a_len": 1, "layers": [{"layer": 0, "PAM": 0.6838161504788332, "QAM": 0.09756367398767907, "SAM": 0.12260474392314791, "heads": [{"head": 0, "PAM": 0.5002431869506836, "QAM": 0.16298165917396545, "SAM": 0.15198931097984314}, {"head": 1, "PAM": 0.0002248941600555554, "QAM": 0.14286160469055176, "SAM": 0.8524389863014221}, {"head": 2, "PAM": 0.5554550290107727, "QAM": 0.14663861691951752, "SAM": 0.13089054822921753}, {"head": 3, "PAM": 0.7453128099441528, "QAM": 0.08623126149177551, "SAM": 0.0899389386177063}, {"head": 4, "PAM": 0.1423267275094986, "QAM": 0.34588828682899475, "SAM": 0.009316587820649147}, {"head": 5, "PAM": 0.7184081673622131, "QAM": 0.09277661144733429, "SAM": 0.09983799606561661}, {"head": 6, "PAM": 0.9020718336105347, "QAM": 0.032831065356731415, "SAM": 0.032264724373817444}, {"head": 7, "PAM": 0.7081997394561768, "QAM": 0.09755054861307144, "SAM": 0.0853562653
# ...

# %%
# !wc -l attention_metrics.jsonl
# Out:
# 266 attention_metrics.jsonl

# %%
import json

records = []
with open("attention_metrics.jsonl", "r") as f:
    for i, line in enumerate(f):
        if i >= 5: break   # first 5 examples
        records.append(json.loads(line))

records[0]
# Out:
# {'id': 'alpaca:22052',
#  'dataset': 'alpaca',
#  'constraint_tags': [],
#  'seq_len': 22,
#  'p_len': 19,
#  'u_len': 1,
#  'a_len': 1,
#  'layers': [{'layer': 0,
#    'PAM': 0.6838161504788332,
#    'QAM': 0.09756367398767907,
#    'SAM': 0.12260474392314791,
#    'heads': [{'head': 0,
#      'PAM': 0.5002431869506836,
#      'QAM': 0.16298165917396545,
#      'SAM': 0.15198931097984314},
#     {'head': 1,
#      'PAM': 0.0002248941600555554,
#      'QAM': 0.14286160469055176,
#      'SAM': 0.8524389863014221},
#     {'head': 2,
#      'PAM': 0.5554550290107727,
#      'QAM': 0.14663861691951752,
#      'SAM': 0.13089054822921753},
#     {'head': 3,
#      'PAM': 0.7453128099441528,
#      'QAM': 0.08623126149177551,
#      'SAM': 0.0899389386177063},
#     {'head': 4,
#      'PAM': 0.1423267275094986,
#      'QAM': 0.34588828682899475,
#      'SAM': 0.009316587820649147},
#     {'head': 5,
#      'PAM': 0.7184081673622131,
#      'QAM': 0.09277661144733429,
# ...
